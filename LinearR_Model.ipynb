# %%
import os 
import sys

# %%
print("--- System Python Paths ---")
print(f"Current Python Executable: {sys.executable}")
print(f"Python Version: {sys.version}")

print("\n--- Conda Environment Verification ---")
print(f"Active Conda Env Name: {os.environ.get('CONDA_DEFAULT_ENV')}")
print(f"Conda Prefix Path:     {os.environ.get('CONDA_PREFIX')}")

print("\n--- Current Working Directory ---")
print(f"Current Folder: {os.getcwd()}")
# Out:
# --- System Python Paths ---
# Current Python Executable: c:\ProgramData\anaconda3\python.exe
# Python Version: 3.12.4 | packaged by Anaconda, Inc. | (main, Jun 18 2024, 15:03:56) [MSC v.1929 64 bit (AMD64)]
#
# --- Conda Environment Verification ---
# Active Conda Env Name: base
# Conda Prefix Path:     C:\ProgramData\anaconda3
#
# --- Current Working Directory ---
# Current Folder: c:\Users\Ashu\Downloads\ML_Project
