# %% [markdown]
# # ML Project Exploration
# This notebook explores the ML project datasets and models.

# %%
import pandas as pd
import numpy as np
from data.preprocessing import load_data, clean_data

# Load and explore data
df = load_data('data/dataset.csv')
print(df.head())
